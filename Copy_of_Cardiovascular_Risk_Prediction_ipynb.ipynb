# %% [markdown]
# <a href="https://colab.research.google.com/github/AruntejaLonka/Cardiovascular-Risk-Prediction/blob/main/Copy_of_Cardiovascular_Risk_Prediction_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Team Members:** 1) ArunTeja Lonka  2) Upasana Kumari  3) Zunaid  4) Sukesh shetty

# %% [markdown]
#  **Problem Statement:**
#  The dataset is from an ongoing cardiovascular study on residents of the town of Framingham, Massachusetts. The classification goal is to predict whether the patient has a 10-year risk of future coronary heart disease (CHD). The dataset provides the patients’ information. It includes over 4,000 records and 15 attributes.

# %% [markdown]
# * Sex: male or female("M" or "F")
# * Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous) Behavioral
# * Is_smoking: whether or not the patient is a current smoker ("YES" or "NO")
# * Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.) Medical( history)
# * BP Meds: whether or not the patient was on blood pressure medication (Nominal)
# * Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
# * Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
# * Diabetes: whether or not the patient had diabetes (Nominal) Medical(current)
# * Tot Chol: total cholesterol level (Continuous)
# * Sys BP: systolic blood pressure (Continuous)
# * Dia BP: diastolic blood pressure (Continuous)
# * BMI: Body Mass Index (Continuous)
# * Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
# * Glucose: glucose level (Continuous) Predict variable (desired target)
# 10-year risk of coronary heart disease CHD(binary: “1”, means “Yes”, “0” means “No”) - DV

# %%
#mounting drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Importing Libraries**

# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score, roc_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
#copy the data set path
path  = "/content/drive/MyDrive/Data sets/data_cardiovascular_risk (1).csv"

# %% [markdown]
# # **Loading Dataset and Analysing**

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
#Identify different charachteristics of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %% [markdown]
# From the above info function we get to know , we have 16 coloumns and 3390 rows in our dataset .

# %%
#Check the Statistical discription of numerical value in dataset
#Crunch the numbers   
df.describe().T
# Out:
#                   count         mean         std     min     25%      50%  \
# id               3390.0  1694.500000  978.753033    0.00  847.25  1694.50
# age              3390.0    49.542183    8.592878   32.00   42.00    49.00
# education        3303.0     1.970936    1.019081    1.00    1.00     2.00
# cigsPerDay       3368.0     9.069477   11.879078    0.00    0.00     0.00
# BPMeds           3346.0     0.029886    0.170299    0.00    0.00     0.00
# prevalentStroke  3390.0     0.006490    0.080309    0.00    0.00     0.00
# prevalentHyp     3390.0     0.315339    0.464719    0.00    0.00     0.00
# diabetes         3390.0     0.025664    0.158153    0.00    0.00     0.00
# totChol          3352.0   237.074284   45.247430  107.00  206.00   234.00
# sysBP            3390.0   132.601180   22.292030   83.50  117.00   128.50
# diaBP            3390.0    82.883038   12.023581   48.00   74.50    82.00
# BMI              3376.0    25.794964    4.115449   15.96   23.02    25.38
# heartRate        3389.0    75.977279   11.971868   45.00   68.00    75.00
# glucose          3086.0    82.086520   24.244753   40.00   71.00    78.00
# TenYearCHD       3390.0     0.150737    0.357846    0.00    0.00     0.00
#
#                      75%     max
# id               2541.75  3389.0
# age                56.00    70.0
# education           3.00     4.0
# cigsPerDay         20.00    70.0
# BPMeds              0.00     1.0
# prevalentStroke     0.00     1.0
# prevalentHyp        1.00     1.0
# diabetes            0.00     1.0
# totChol           264.00   696.0
# sysBP             144.00   295.0
# diaBP              90.00   142.5
# BMI                28.04    56.8
# heartRate          83.00   143.0
# glucose            87.00   394.0
# TenYearCHD          0.00     1.0

# %% [markdown]
# Under Statistical discription of numerical value in dataset ,we get Know there are some outliers in data..

# %% [markdown]
# ## **Missing/NULL Values Treatment**

# %% [markdown]
# Looking for the lost souls
# Why look for the null values? - these unrecorded information might play a prominent role in our analysis by providing us with important answers to hidden questions, might even lead us towards false predicitons and sometimes may not even affect at all. So it's always a better practice to catch the lost souls before moving on.
#
# Few doubts that pop up in our analytical minds are...
#
# How ubiquitous are the missing values?
# Are they random?
# Do they show a pattern?

# %%
#Visualize the missing values
import missingno as msno
plt.figure(facecolor='lightgray')
msno.bar(df,color='blue',figsize=[12,3],fontsize=10)
plt.show()

# %% [markdown]
# ## Moving on with the next steps, let's take a sneak peek at the count and percentages of the null values before we proceed further...

# %%
#Dig into the count and percentages
tot_missing = df.isnull().sum().sort_values(ascending=False)
percent_missing = (df.isnull().sum()* 100 / len(df)).round(2).sort_values(ascending=False)
lost_souls = pd.concat([tot_missing, percent_missing], axis=1, keys=['Total', 'Percentage'])
lost_souls.head(20)
# Out:
#                  Total  Percentage
# glucose            304        8.97
# education           87        2.57
# BPMeds              44        1.30
# totChol             38        1.12
# cigsPerDay          22        0.65
# BMI                 14        0.41
# heartRate            1        0.03
# id                   0        0.00
# diaBP                0        0.00
# sysBP                0        0.00
# prevalentHyp         0        0.00
# diabetes             0        0.00
# age                  0        0.00
# prevalentStroke      0        0.00
# is_smoking           0        0.00
# sex                  0        0.00
# TenYearCHD           0        0.00

# %%
#Visualize the numbers
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(12,5)})

vis_missing = sns.barplot(x=lost_souls.index, y='Percentage', data=lost_souls)

vis_missing.set_title('Missing Values', fontsize = 18)
vis_missing.set_xticklabels(vis_missing.get_xmajorticklabels(), fontsize =10, rotation=90)
plt.show()

# %% [markdown]
# Mmmmm...magnificent! This reveals columns "glucose" , "education","BPMeds" , 'totChol', "cigsPerDay", and "BMI".
# only need a quick replacement with the ever loving number '0' used when filling up the null values in data analysis. But before that let's get rid of the unwanted!

# %%
df = df.fillna({'glucose':(df['glucose'].mean()),
                'education':1,
                'BPMeds':0,
                'totChol':(df['totChol'].mean()),
                'cigsPerDay':0,
                "BMI":(df['BMI'].mean()),
                'heartRate':(df['heartRate'].mean())
                })

# %% [markdown]
# We are fill null values of this coloumns (glucose,totChol,BMI,heartRate) with Statisticalmean of the data,and other then these we fill with 0 or 1 .

# %%
#Afer data inputation we will cross check tthe null values
df.isnull().sum()
# Out:
# id                 0
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3390 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3390 non-null   float64
#  6   BPMeds           3390 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3390 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3390 non-null   float64
#  14  heartRate        3390 non-null   float64
#  15  glucose          3390 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %%
#Kick out the misfits
df.drop(['id'],axis=1,inplace=True)

# %% [markdown]
# Voila! Done and dusted! Removing the misfits have cleared the path to a better concise understanding of the dataset. What else is better than data that's not noisy!
#
# But, One more step to go...

# %% [markdown]
# Bringing in the most wanted!

# %%
#Shows the required data
list(df.columns)
# Out:
# ['age',
#  'education',
#  'sex',
#  'is_smoking',
#  'cigsPerDay',
#  'BPMeds',
#  'prevalentStroke',
#  'prevalentHyp',
#  'diabetes',
#  'totChol',
#  'sysBP',
#  'diaBP',
#  'BMI',
#  'heartRate',
#  'glucose',
#  'TenYearCHD']

# %%
indep = ['age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose']

# %%
dep = ['TenYearCHD']

# %% [markdown]
# # **Explanatory Data Analysis**

# %%
#Storing all the features which has continuous values
continuous_variables = ['age','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
other_variables = ['education','sex','is_smoking','prevalentStroke','prevalentHyp','diabetes']

# %%
#Analyzing the distribution of all the features which has continuous values
for col in continuous_variables:
  sns.displot(df[col])
plt.show()

# %%
#Counting all the encoded values where dependent variable is the parameter
for col in indep:
  sns.countplot(x=df[col],hue=df['TenYearCHD'],data=df)
  plt.show()

# %%
#Counting all the encoded values where dependent variable is the parameter
for col in other_variables:
  sns.countplot(x=df[col],hue=df['TenYearCHD'],data=df)
  plt.show()

# %% [markdown]
# # Handling Outliers

# %%
#Box Plot for analyzing the outliers
df.plot(kind='box',figsize=(16,8))

# %% [markdown]
# By the above boxplot we will which features haveing outliers.
#
#
# cigsPerDay,totChol,sysBP,diaBP,BMI,heartRate,glucose. these features having outliers..
#
# then we can store all outliers containg coloumns in one  list to remove the outliers.

# %%
#Stored all the features where we want to remove outliers
outlier_col = ['cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
#Analyzing the outlier columns
for col in outlier_col:
  sns.boxplot(x=df['TenYearCHD'],y=df[col],data=df)
  plt.show()

# %% [markdown]
# As per our visuvalisation of outliers, we are setting the range of quatile (0.15 to .085) ,to make our data clean and outlier free.

# %%
#Handling Outliers
df[outlier_col]=df[outlier_col].clip(lower=df[outlier_col].quantile(0.15),upper=df[outlier_col].quantile(0.85),axis=1)

# %% [markdown]
# After performing outlier treatment, we can visuvalise our outlier free data..

# %%
#Box plot after handling outliers
df.plot(kind='box',figsize=(16,8))

# %% [markdown]
# Here we can  see the outlier free data form the above box plot..

# %%
for col in outlier_col:
  sns.boxplot(x=df['TenYearCHD'],y=df[col],data=df)
  plt.show()

# %% [markdown]
# # Multicollinearity & Feature Selection

# %% [markdown]
# Multicollinearity is a statistical concept where several independent variables in a model are correlated.

# %%
# Heatmap:
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(),annot=True,cmap=plt.cm.CMRmap_r)

# %% [markdown]
# As per our graph we can see some  features having high collinearity with other independent features.

# %%
import numpy as np
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.7)
len(set(corr_features))
# Out:
# 2

# %% [markdown]
# Afer putting the threshold as 0.7 we can get two features are highly corelated

# %%
corr_features
# Out:
# {'diaBP', 'sysBP'}

# %%
#As per the higher corelation of these two coloumns, we are droping those features and make a copy of data for further analysis..
df_copy = df.drop(corr_features,axis=1)

# %%
df_copy
# Out:
#       age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0      64        2.0   F        YES         3.0     0.0                0
# 1      36        4.0   M         NO         0.0     0.0                0
# 2      46        1.0   F        YES        10.0     0.0                0
# 3      50        1.0   M        YES        20.0     0.0                0
# 4      64        1.0   F        YES        20.0     0.0                0
# ...   ...        ...  ..        ...         ...     ...              ...
# 3385   60        1.0   F         NO         0.0     0.0                0
# 3386   46        1.0   F         NO         0.0     0.0                0
# 3387   44        3.0   M        YES         3.0     0.0                0
# 3388   60        1.0   M         NO         0.0     0.0                0
# 3389   54        3.0   F         NO         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol        BMI  heartRate  glucose  \
# 0                0         0    221.0  25.794964       88.0     80.0
# 1                1         0    212.0  29.590000       72.0     75.0
# 2                0         0    250.0  21.820000       88.0     92.0
# 3                1         0    233.0  28.260000       68.0     92.0
# 4                0         0    241.0  26.420000       70.0     77.0
# ...            ...       ...      ...        ...        ...      ...
# 3385             0         0    261.0  29.280000       70.0     92.0
# 3386             0         0    199.0  21.960000       80.0     84.0
# 3387             1         0    280.0  28.920000       73.0     72.0
# 3388             1         0    193.0  23.010000       80.0     85.0
# 3389             0         0    280.0  29.590000       79.0     92.0
#
#       TenYearCHD
# 0              1
# 1              0
# 2              0
# 3              1
# 4              0
# ...          ...
# 3385           0
# 3386           0
# 3387           1
# 3388           0
# 3389           0
#
# [3390 rows x 14 columns]

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Machine can't understand the textual / Categorical data so, we need to convert it in to numarical formate..

# %%
#Mapping the Variables
df_copy['is_smoking']=df_copy['is_smoking'].map({'YES':1,'NO':0})
df_copy['sex']=df_copy['sex'].map({'M':0,'F':1})

# %%
X = df_copy.iloc[:,0:-1].values
y=df_copy['TenYearCHD'].values

# %%
df_copy.head()
# Out:
#    age  education  sex  is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   64        2.0    1           1         3.0     0.0                0
# 1   36        4.0    0           0         0.0     0.0                0
# 2   46        1.0    1           1        10.0     0.0                0
# 3   50        1.0    0           1        20.0     0.0                0
# 4   64        1.0    1           1        20.0     0.0                0
#
#    prevalentHyp  diabetes  totChol        BMI  heartRate  glucose  TenYearCHD
# 0             0         0    221.0  25.794964       88.0     80.0           1
# 1             1         0    212.0  29.590000       72.0     75.0           0
# 2             0         0    250.0  21.820000       88.0     92.0           0
# 3             1         0    233.0  28.260000       68.0     92.0           1
# 4             0         0    241.0  26.420000       70.0     77.0           0

# %% [markdown]
# # Splitting & Scaling data

# %%
# separate dataset into train and test splits
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((2712, 13), (678, 13))

# %%
#Checking the shape of our training and testing datasets
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2712, 13)
# (678, 13)
# (2712,)
# (678,)

# %%
#Using Standard Scaler to scale 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 
X_train = scaler.fit_transform(X_train) 
X_test = scaler.transform(X_test)

# %%
X.shape,y.shape
# Out:
# ((3390, 13), (3390,))

# %% [markdown]
# # Implementing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Log = LogisticRegression()

# %%
#Fitting the training datasets
Log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predicting on training dataset
y_pred_log_train = Log.predict(X_train)

# %%
#predicting on testing dataset
y_pred_log_test = Log.predict(X_test)

# %% [markdown]
# ## Classification Evaluation Metrics on Logistic Regression.

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#Accuracy score of training
log_acc_train = accuracy_score(y_train,y_pred_log_train)*100
log_acc_train
# Out:
# 85.50884955752213

# %%
#Classification Report of training
print(classification_report(y_train,y_pred_log_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      2305
#            1       0.67      0.07      0.12       407
#
#     accuracy                           0.86      2712
#    macro avg       0.76      0.53      0.52      2712
# weighted avg       0.83      0.86      0.80      2712

# %%
#Classification report of testing
print(classification_report(y_test,y_pred_log_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       574
#            1       0.73      0.08      0.14       104
#
#     accuracy                           0.85       678
#    macro avg       0.79      0.54      0.53       678
# weighted avg       0.84      0.85      0.80       678

# %% [markdown]
# AS our data is highly imbalance so we have to improve this, using  Smotek Technique..

# %% [markdown]
# # Using Smotek Technique

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
# Implementing Oversampling for Handling Imbalanced 
smk = SMOTETomek(random_state=60)
X_res,y_res=smk.fit_resample(X,y)

# %%
X_res.shape,y_res.shape,X.shape,y.shape
# Out:
# ((5658, 13), (5658,), (3390, 13), (3390,))

# %% [markdown]
# ##Splitting & scaling data after Smotek Technique

# %%
#Splitting the data
X_train_res, X_test_res, y_train_res, y_test_res = train_test_split(X_res, y_res, test_size = 0.30, random_state=300)

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((3960, 13), (3960,))

# %%
#Scaling the data
X_train_res = scaler.fit_transform(X_train_res)
X_test_res = scaler.transform(X_test_res)

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((3960, 13), (3960,))

# %% [markdown]
# # Implementing Logistic Regression after using Smotek Technique

# %%
model_smotek = LogisticRegression()

# %%
model_smotek.fit(X_train_res,y_train_res)
# Out:
# LogisticRegression()

# %%
y_pred_smotek_train = model_smotek.predict(X_train_res)

# %%
y_pred_smotek_test = model_smotek.predict(X_test_res)

# %%
#Accuaracy score of training
log_acc_train = accuracy_score(y_train_res,y_pred_smotek_train)*100
log_acc_train
# Out:
# 67.62626262626263

# %%
#Accuaracy score of training
log_acc_test = accuracy_score(y_test_res,y_pred_smotek_test)*100
log_acc_test
# Out:
# 67.78563015312132

# %% [markdown]
# ## Classification Evaluation Metrics on Logistic Regression after using Smotek Technique.

# %%
#Classification report of training
print(classification_report(y_train_res,y_pred_smotek_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67      1974
#            1       0.67      0.69      0.68      1986
#
#     accuracy                           0.68      3960
#    macro avg       0.68      0.68      0.68      3960
# weighted avg       0.68      0.68      0.68      3960

# %%
#Classification report of testing
print(classification_report(y_test_res,y_pred_smotek_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.67      0.68       855
#            1       0.67      0.69      0.68       843
#
#     accuracy                           0.68      1698
#    macro avg       0.68      0.68      0.68      1698
# weighted avg       0.68      0.68      0.68      1698

# %% [markdown]
# From the above Classification report  our data is well balanced and traing and test accuracy  almost same i.e, 68%

# %% [markdown]
# #**RANDOM FOREST**

# %%
from sklearn.ensemble import  RandomForestClassifier

# %%
rfc = RandomForestClassifier(max_depth=4, random_state=20)
#Fitting Random Forest Classifier on training dataset
rfc.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(max_depth=4, random_state=20)

# %%
#predicting on training & testing datasets
rfc_pred_train = rfc.predict(X_train_res)
rfc_pred_test = rfc.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on  RandomForest

# %%
#Accuracy score, confusion matrix and classification report of training
rfc_acc_train = accuracy_score(y_train_res,rfc_pred_train)*100
print(rfc_acc_train)
print(confusion_matrix(y_train_res,rfc_pred_train))
print(classification_report(y_train_res,rfc_pred_train))
# Out:
# 80.85858585858587
# [[1568  406]
#  [ 352 1634]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81      1974
#            1       0.80      0.82      0.81      1986
#
#     accuracy                           0.81      3960
#    macro avg       0.81      0.81      0.81      3960
# weighted avg       0.81      0.81      0.81      3960

# %%
#Accuracy score, confusion matrix and classification report of testing
rfc_acc_test = accuracy_score(y_test_res,rfc_pred_test)*100
print(rfc_acc_test)
print(confusion_matrix(y_test_res,rfc_pred_test))
print(classification_report(y_test_res,rfc_pred_test))
# Out:
# 79.0341578327444
# [[673 182]
#  [174 669]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       855
#            1       0.79      0.79      0.79       843
#
#     accuracy                           0.79      1698
#    macro avg       0.79      0.79      0.79      1698
# weighted avg       0.79      0.79      0.79      1698

# %% [markdown]
# From the above Classification report  our data is well balanced and traing and test accuracy  almost same i.e, 79%  and 80% respectively..

# %%
roc_auc_score(y_test_res,rfc_pred_test)
# Out:
# 0.7903644044868994

# %% [markdown]
# # KNN

# %%
from pandas.core.common import random_state
# Import KNeighborsClassifier 
from sklearn.neighbors import KNeighborsClassifier

#Setup arrays to store training and test accuracies
neighbors = np.arange(1,20)
train_accuracy =np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    # Setup a knn classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k,leaf_size=30,weights="uniform")
    
    # Fit the model
    knn.fit(X_train_res, y_train_res)
    
    # Compute accuracy on the training set
    train_accuracy[i] = knn.score(X_train_res, y_train_res)
    
    # Compute accuracy on the test set
    test_accuracy[i] = knn.score(X_test_res, y_test_res)

# %%
# Generate plot
plt.title('k-NN Varying number of neighbors')
plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
plt.plot(neighbors, train_accuracy, label='Training accuracy')
plt.legend()
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# from the above graph we can select k=12 as a best parameter to avoid over and underfitting..

# %%
# Setup a knn classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=12)

# %%
# Fit the model
knn.fit(X_train_res,y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
# Import confusion_matrix
from sklearn.metrics import confusion_matrix,roc_curve

# %%
# Let us get the predictions using the classifier we had fit above
y_pred_test = knn.predict(X_test_res)
y_pred_train = knn.predict(X_train_res)

# %% [markdown]
# ## Classification Evaluation Metrics on KNN

# %%
#Accuracy score, confusion matrix and classification report of training 
knn_acc_train = accuracy_score(y_train_res,y_pred_train)*100
print(knn_acc_train)
print(confusion_matrix(y_train_res,y_pred_train))
print(classification_report(y_train_res,y_pred_train))
# Out:
# 81.18686868686868
# [[1509  465]
#  [ 280 1706]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80      1974
#            1       0.79      0.86      0.82      1986
#
#     accuracy                           0.81      3960
#    macro avg       0.81      0.81      0.81      3960
# weighted avg       0.81      0.81      0.81      3960

# %%
#Accuracy score, confusion matrix and classification report of testing
knn_acc_test = accuracy_score(y_test_res,y_pred_test)*100
print(rfc_acc_test)
print(confusion_matrix(y_test_res,y_pred_test))
print(classification_report(y_test_res,y_pred_test))
# Out:
# 79.0341578327444
# [[611 244]
#  [151 692]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.76       855
#            1       0.74      0.82      0.78       843
#
#     accuracy                           0.77      1698
#    macro avg       0.77      0.77      0.77      1698
# weighted avg       0.77      0.77      0.77      1698

# %% [markdown]
# From the above Classification report  our data is well balanced and traing and test accuracy  almost same i.e, 79%  and 81% respectively..

# %%
y_pred_proba = knn.predict_proba(X_test)[:,1]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='Knn')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('Knn(n_neighbors=12) ROC curve')
plt.show()

# %%
# Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.8224420396676494

# %% [markdown]
# # Implementing Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc = SVC(C=100,gamma=0.001,kernel='rbf')

# %%
#Fitting SVM on training dataset
svc.fit(X_train_res,y_train_res)
# Out:
# SVC(C=100, gamma=0.001)

# %%
#predicting on training dataset
y_pred_train_svm = svc.predict(X_train_res)

# %%
#predicting on testing dataset
y_pred_test_svm = svc.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on SVM.

# %%
#Accuracy score, confusion matrix and classification report of training 
acc_svm_train= accuracy_score(y_pred_train_svm,y_train_res)*100
print(acc_svm_train)
cmm = confusion_matrix(y_pred_train_svm,y_train_res)
print(cmm)
crr = classification_report(y_pred_train_svm,y_train_res)
print(crr)
# Out:
# 72.55050505050505
# [[1365  478]
#  [ 609 1508]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.72      1843
#            1       0.76      0.71      0.74      2117
#
#     accuracy                           0.73      3960
#    macro avg       0.73      0.73      0.73      3960
# weighted avg       0.73      0.73      0.73      3960

# %%
#Accuracy score, confusion matrix and classification report of testing
acc_svm_test = accuracy_score(y_test_res,y_pred_test_svm)*100
print(acc_svm_test)
print(confusion_matrix(y_pred_test_svm,y_test_res))
print(classification_report(y_pred_test_svm,y_test_res))
# Out:
# 71.08362779740872
# [[580 216]
#  [275 627]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70       796
#            1       0.74      0.70      0.72       902
#
#     accuracy                           0.71      1698
#    macro avg       0.71      0.71      0.71      1698
# weighted avg       0.71      0.71      0.71      1698

# %% [markdown]
# From the above Classification report  our data is well balanced and traing and test accuracy  almost same i.e, 72%  and 71% respectively..

# %% [markdown]
# # Hyperparameter tuning using GridSearchCV on SVM

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.metrics.pairwise import linear_kernel
#Making a parameters dict where all parameters is of SVM
param_grid={'C':[0.1,1,8,10,12,16,20,30,50,80,100,1000],'gamma':[1,0.1,0.001,0.0001],'kernel':['rbf','linear_kernel']}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=100)

# %%
#Fitting on training dataset
grid.fit(X_train_res,y_train_res)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5; 1/96] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 1/5; 1/96] END ..C=0.1, gamma=1, kernel=rbf;, score=0.572 total time=   0.8s
# [CV 2/5; 1/96] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 2/5; 1/96] END ..C=0.1, gamma=1, kernel=rbf;, score=0.547 total time=   0.9s
# [CV 3/5; 1/96] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 3/5; 1/96] END ..C=0.1, gamma=1, kernel=rbf;, score=0.528 total time=   0.9s
# [CV 4/5; 1/96] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 4/5; 1/96] END ..C=0.1, gamma=1, kernel=rbf;, score=0.551 total time=   0.8s
# [CV 5/5; 1/96] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 5/5; 1/96] END ..C=0.1, gamma=1, kernel=rbf;, score=0.533 total time=   0.8s
# [CV 1/5; 2/96] START C=0.1, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 2/96] END C=0.1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 2/96] START C=0.1, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 2/96] END C=0.1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 2/96] START C=0.1, gamma=1, kernel=linear_kernel.......................
# [CV 3/5; 2/96] END C=0.1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 2/96] START C=0.1, gamma=1, kernel=linear_kernel.......................
# [CV 4/5; 2/96] END C=0.1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 2/96] START C=0.1, gamma=1, kernel=linear_kernel.......................
# [CV 5/5; 2/96] END C=0.1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 3/96] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 3/96] END C=0.1, gamma=0.1, kernel=rbf;, score=0.703 total time=   0.7s
# [CV 2/5; 3/96] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 3/96] END C=0.1, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.7s
# [CV 3/5; 3/96] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 3/96] END C=0.1, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.8s
# [CV 4/5; 3/96] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 3/96] END C=0.1, gamma=0.1, kernel=rbf;, score=0.678 total time=   0.8s
# [CV 5/5; 3/96] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 3/96] END C=0.1, gamma=0.1, kernel=rbf;, score=0.726 total time=   0.7s
# [CV 1/5; 4/96] START C=0.1, gamma=0.1, kernel=linear_kernel.....................
# [CV 1/5; 4/96] END C=0.1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 4/96] START C=0.1, gamma=0.1, kernel=linear_kernel.....................
# [CV 2/5; 4/96] END C=0.1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 4/96] START C=0.1, gamma=0.1, kernel=linear_kernel.....................
# [CV 3/5; 4/96] END C=0.1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 4/96] START C=0.1, gamma=0.1, kernel=linear_kernel.....................
# [CV 4/5; 4/96] END C=0.1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 4/96] START C=0.1, gamma=0.1, kernel=linear_kernel.....................
# [CV 5/5; 4/96] END C=0.1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 5/96] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 5/96] END C=0.1, gamma=0.001, kernel=rbf;, score=0.648 total time=   0.9s
# [CV 2/5; 5/96] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 5/96] END C=0.1, gamma=0.001, kernel=rbf;, score=0.644 total time=   0.9s
# [CV 3/5; 5/96] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 5/96] END C=0.1, gamma=0.001, kernel=rbf;, score=0.652 total time=   0.9s
# [CV 4/5; 5/96] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 5/96] END C=0.1, gamma=0.001, kernel=rbf;, score=0.659 total time=   0.9s
# [CV 5/5; 5/96] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 5/96] END C=0.1, gamma=0.001, kernel=rbf;, score=0.687 total time=   0.9s
# [CV 1/5; 6/96] START C=0.1, gamma=0.001, kernel=linear_kernel...................
# [CV 1/5; 6/96] END C=0.1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 6/96] START C=0.1, gamma=0.001, kernel=linear_kernel...................
# [CV 2/5; 6/96] END C=0.1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 6/96] START C=0.1, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 6/96] END C=0.1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 6/96] START C=0.1, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 6/96] END C=0.1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 6/96] START C=0.1, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 6/96] END C=0.1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 7/96] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 7/96] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.9s
# [CV 2/5; 7/96] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 7/96] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   0.9s
# [CV 3/5; 7/96] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 7/96] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   0.8s
# [CV 4/5; 7/96] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 7/96] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   0.9s
# [CV 5/5; 7/96] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 7/96] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   0.9s
# [CV 1/5; 8/96] START C=0.1, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 8/96] END C=0.1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 8/96] START C=0.1, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 8/96] END C=0.1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 8/96] START C=0.1, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 8/96] END C=0.1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 8/96] START C=0.1, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 8/96] END C=0.1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 8/96] START C=0.1, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 8/96] END C=0.1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 9/96] START C=1, gamma=1, kernel=rbf...................................
# [CV 1/5; 9/96] END ....C=1, gamma=1, kernel=rbf;, score=0.869 total time=   1.0s
# [CV 2/5; 9/96] START C=1, gamma=1, kernel=rbf...................................
# [CV 2/5; 9/96] END ....C=1, gamma=1, kernel=rbf;, score=0.876 total time=   1.0s
# [CV 3/5; 9/96] START C=1, gamma=1, kernel=rbf...................................
# [CV 3/5; 9/96] END ....C=1, gamma=1, kernel=rbf;, score=0.879 total time=   1.0s
# [CV 4/5; 9/96] START C=1, gamma=1, kernel=rbf...................................
# [CV 4/5; 9/96] END ....C=1, gamma=1, kernel=rbf;, score=0.872 total time=   0.9s
# [CV 5/5; 9/96] START C=1, gamma=1, kernel=rbf...................................
# [CV 5/5; 9/96] END ....C=1, gamma=1, kernel=rbf;, score=0.859 total time=   1.0s
# [CV 1/5; 10/96] START C=1, gamma=1, kernel=linear_kernel........................
# [CV 1/5; 10/96] END C=1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 10/96] START C=1, gamma=1, kernel=linear_kernel........................
# [CV 2/5; 10/96] END C=1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 10/96] START C=1, gamma=1, kernel=linear_kernel........................
# [CV 3/5; 10/96] END C=1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 10/96] START C=1, gamma=1, kernel=linear_kernel........................
# [CV 4/5; 10/96] END C=1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 10/96] START C=1, gamma=1, kernel=linear_kernel........................
# [CV 5/5; 10/96] END C=1, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 11/96] START C=1, gamma=0.1, kernel=rbf................................
# [CV 1/5; 11/96] END .C=1, gamma=0.1, kernel=rbf;, score=0.769 total time=   0.6s
# [CV 2/5; 11/96] START C=1, gamma=0.1, kernel=rbf................................
# [CV 2/5; 11/96] END .C=1, gamma=0.1, kernel=rbf;, score=0.780 total time=   0.6s
# [CV 3/5; 11/96] START C=1, gamma=0.1, kernel=rbf................................
# [CV 3/5; 11/96] END .C=1, gamma=0.1, kernel=rbf;, score=0.790 total time=   0.6s
# [CV 4/5; 11/96] START C=1, gamma=0.1, kernel=rbf................................
# [CV 4/5; 11/96] END .C=1, gamma=0.1, kernel=rbf;, score=0.795 total time=   0.6s
# [CV 5/5; 11/96] START C=1, gamma=0.1, kernel=rbf................................
# [CV 5/5; 11/96] END .C=1, gamma=0.1, kernel=rbf;, score=0.816 total time=   0.6s
# [CV 1/5; 12/96] START C=1, gamma=0.1, kernel=linear_kernel......................
# [CV 1/5; 12/96] END C=1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 12/96] START C=1, gamma=0.1, kernel=linear_kernel......................
# [CV 2/5; 12/96] END C=1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 12/96] START C=1, gamma=0.1, kernel=linear_kernel......................
# [CV 3/5; 12/96] END C=1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 12/96] START C=1, gamma=0.1, kernel=linear_kernel......................
# [CV 4/5; 12/96] END C=1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 12/96] START C=1, gamma=0.1, kernel=linear_kernel......................
# [CV 5/5; 12/96] END C=1, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 13/96] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 1/5; 13/96] END C=1, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.7s
# [CV 2/5; 13/96] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 2/5; 13/96] END C=1, gamma=0.001, kernel=rbf;, score=0.674 total time=   0.7s
# [CV 3/5; 13/96] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 3/5; 13/96] END C=1, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.7s
# [CV 4/5; 13/96] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 4/5; 13/96] END C=1, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.7s
# [CV 5/5; 13/96] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 5/5; 13/96] END C=1, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.7s
# [CV 1/5; 14/96] START C=1, gamma=0.001, kernel=linear_kernel....................
# [CV 1/5; 14/96] END C=1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 14/96] START C=1, gamma=0.001, kernel=linear_kernel....................
# [CV 2/5; 14/96] END C=1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 14/96] START C=1, gamma=0.001, kernel=linear_kernel....................
# [CV 3/5; 14/96] END C=1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 14/96] START C=1, gamma=0.001, kernel=linear_kernel....................
# [CV 4/5; 14/96] END C=1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 14/96] START C=1, gamma=0.001, kernel=linear_kernel....................
# [CV 5/5; 14/96] END C=1, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 15/96] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 1/5; 15/96] END C=1, gamma=0.0001, kernel=rbf;, score=0.646 total time=   0.9s
# [CV 2/5; 15/96] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 2/5; 15/96] END C=1, gamma=0.0001, kernel=rbf;, score=0.648 total time=   0.8s
# [CV 3/5; 15/96] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 3/5; 15/96] END C=1, gamma=0.0001, kernel=rbf;, score=0.648 total time=   0.8s
# [CV 4/5; 15/96] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 4/5; 15/96] END C=1, gamma=0.0001, kernel=rbf;, score=0.652 total time=   0.9s
# [CV 5/5; 15/96] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 5/5; 15/96] END C=1, gamma=0.0001, kernel=rbf;, score=0.682 total time=   0.9s
# [CV 1/5; 16/96] START C=1, gamma=0.0001, kernel=linear_kernel...................
# [CV 1/5; 16/96] END C=1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 16/96] START C=1, gamma=0.0001, kernel=linear_kernel...................
# [CV 2/5; 16/96] END C=1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 16/96] START C=1, gamma=0.0001, kernel=linear_kernel...................
# [CV 3/5; 16/96] END C=1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 16/96] START C=1, gamma=0.0001, kernel=linear_kernel...................
# [CV 4/5; 16/96] END C=1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 16/96] START C=1, gamma=0.0001, kernel=linear_kernel...................
# [CV 5/5; 16/96] END C=1, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 17/96] START C=8, gamma=1, kernel=rbf..................................
# [CV 1/5; 17/96] END ...C=8, gamma=1, kernel=rbf;, score=0.872 total time=   0.9s
# [CV 2/5; 17/96] START C=8, gamma=1, kernel=rbf..................................
# [CV 2/5; 17/96] END ...C=8, gamma=1, kernel=rbf;, score=0.880 total time=   0.9s
# [CV 3/5; 17/96] START C=8, gamma=1, kernel=rbf..................................
# [CV 3/5; 17/96] END ...C=8, gamma=1, kernel=rbf;, score=0.881 total time=   1.0s
# [CV 4/5; 17/96] START C=8, gamma=1, kernel=rbf..................................
# [CV 4/5; 17/96] END ...C=8, gamma=1, kernel=rbf;, score=0.866 total time=   0.9s
# [CV 5/5; 17/96] START C=8, gamma=1, kernel=rbf..................................
# [CV 5/5; 17/96] END ...C=8, gamma=1, kernel=rbf;, score=0.861 total time=   0.9s
# [CV 1/5; 18/96] START C=8, gamma=1, kernel=linear_kernel........................
# [CV 1/5; 18/96] END C=8, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 18/96] START C=8, gamma=1, kernel=linear_kernel........................
# [CV 2/5; 18/96] END C=8, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 18/96] START C=8, gamma=1, kernel=linear_kernel........................
# [CV 3/5; 18/96] END C=8, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 18/96] START C=8, gamma=1, kernel=linear_kernel........................
# [CV 4/5; 18/96] END C=8, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 18/96] START C=8, gamma=1, kernel=linear_kernel........................
# [CV 5/5; 18/96] END C=8, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 19/96] START C=8, gamma=0.1, kernel=rbf................................
# [CV 1/5; 19/96] END .C=8, gamma=0.1, kernel=rbf;, score=0.827 total time=   0.6s
# [CV 2/5; 19/96] START C=8, gamma=0.1, kernel=rbf................................
# [CV 2/5; 19/96] END .C=8, gamma=0.1, kernel=rbf;, score=0.826 total time=   0.6s
# [CV 3/5; 19/96] START C=8, gamma=0.1, kernel=rbf................................
# [CV 3/5; 19/96] END .C=8, gamma=0.1, kernel=rbf;, score=0.827 total time=   0.6s
# [CV 4/5; 19/96] START C=8, gamma=0.1, kernel=rbf................................
# [CV 4/5; 19/96] END .C=8, gamma=0.1, kernel=rbf;, score=0.835 total time=   0.6s
# [CV 5/5; 19/96] START C=8, gamma=0.1, kernel=rbf................................
# [CV 5/5; 19/96] END .C=8, gamma=0.1, kernel=rbf;, score=0.845 total time=   0.6s
# [CV 1/5; 20/96] START C=8, gamma=0.1, kernel=linear_kernel......................
# [CV 1/5; 20/96] END C=8, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 20/96] START C=8, gamma=0.1, kernel=linear_kernel......................
# [CV 2/5; 20/96] END C=8, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 20/96] START C=8, gamma=0.1, kernel=linear_kernel......................
# [CV 3/5; 20/96] END C=8, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 20/96] START C=8, gamma=0.1, kernel=linear_kernel......................
# [CV 4/5; 20/96] END C=8, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 20/96] START C=8, gamma=0.1, kernel=linear_kernel......................
# [CV 5/5; 20/96] END C=8, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 21/96] START C=8, gamma=0.001, kernel=rbf..............................
# [CV 1/5; 21/96] END C=8, gamma=0.001, kernel=rbf;, score=0.674 total time=   0.7s
# [CV 2/5; 21/96] START C=8, gamma=0.001, kernel=rbf..............................
# [CV 2/5; 21/96] END C=8, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.7s
# [CV 3/5; 21/96] START C=8, gamma=0.001, kernel=rbf..............................
# [CV 3/5; 21/96] END C=8, gamma=0.001, kernel=rbf;, score=0.688 total time=   0.7s
# [CV 4/5; 21/96] START C=8, gamma=0.001, kernel=rbf..............................
# [CV 4/5; 21/96] END C=8, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.7s
# [CV 5/5; 21/96] START C=8, gamma=0.001, kernel=rbf..............................
# [CV 5/5; 21/96] END C=8, gamma=0.001, kernel=rbf;, score=0.711 total time=   0.7s
# [CV 1/5; 22/96] START C=8, gamma=0.001, kernel=linear_kernel....................
# [CV 1/5; 22/96] END C=8, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 22/96] START C=8, gamma=0.001, kernel=linear_kernel....................
# [CV 2/5; 22/96] END C=8, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 22/96] START C=8, gamma=0.001, kernel=linear_kernel....................
# [CV 3/5; 22/96] END C=8, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 22/96] START C=8, gamma=0.001, kernel=linear_kernel....................
# [CV 4/5; 22/96] END C=8, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 22/96] START C=8, gamma=0.001, kernel=linear_kernel....................
# [CV 5/5; 22/96] END C=8, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 23/96] START C=8, gamma=0.0001, kernel=rbf.............................
# [CV 1/5; 23/96] END C=8, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 2/5; 23/96] START C=8, gamma=0.0001, kernel=rbf.............................
# [CV 2/5; 23/96] END C=8, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.7s
# [CV 3/5; 23/96] START C=8, gamma=0.0001, kernel=rbf.............................
# [CV 3/5; 23/96] END C=8, gamma=0.0001, kernel=rbf;, score=0.674 total time=   0.7s
# [CV 4/5; 23/96] START C=8, gamma=0.0001, kernel=rbf.............................
# [CV 4/5; 23/96] END C=8, gamma=0.0001, kernel=rbf;, score=0.668 total time=   0.7s
# [CV 5/5; 23/96] START C=8, gamma=0.0001, kernel=rbf.............................
# [CV 5/5; 23/96] END C=8, gamma=0.0001, kernel=rbf;, score=0.708 total time=   0.7s
# [CV 1/5; 24/96] START C=8, gamma=0.0001, kernel=linear_kernel...................
# [CV 1/5; 24/96] END C=8, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 24/96] START C=8, gamma=0.0001, kernel=linear_kernel...................
# [CV 2/5; 24/96] END C=8, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 24/96] START C=8, gamma=0.0001, kernel=linear_kernel...................
# [CV 3/5; 24/96] END C=8, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 24/96] START C=8, gamma=0.0001, kernel=linear_kernel...................
# [CV 4/5; 24/96] END C=8, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 24/96] START C=8, gamma=0.0001, kernel=linear_kernel...................
# [CV 5/5; 24/96] END C=8, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 25/96] START C=10, gamma=1, kernel=rbf.................................
# [CV 1/5; 25/96] END ..C=10, gamma=1, kernel=rbf;, score=0.870 total time=   1.0s
# [CV 2/5; 25/96] START C=10, gamma=1, kernel=rbf.................................
# [CV 2/5; 25/96] END ..C=10, gamma=1, kernel=rbf;, score=0.879 total time=   0.9s
# [CV 3/5; 25/96] START C=10, gamma=1, kernel=rbf.................................
# [CV 3/5; 25/96] END ..C=10, gamma=1, kernel=rbf;, score=0.881 total time=   1.0s
# [CV 4/5; 25/96] START C=10, gamma=1, kernel=rbf.................................
# [CV 4/5; 25/96] END ..C=10, gamma=1, kernel=rbf;, score=0.866 total time=   1.0s
# [CV 5/5; 25/96] START C=10, gamma=1, kernel=rbf.................................
# [CV 5/5; 25/96] END ..C=10, gamma=1, kernel=rbf;, score=0.860 total time=   1.0s
# [CV 1/5; 26/96] START C=10, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 26/96] END C=10, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 26/96] START C=10, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 26/96] END C=10, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 26/96] START C=10, gamma=1, kernel=linear_kernel.......................
# [CV 3/5; 26/96] END C=10, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 26/96] START C=10, gamma=1, kernel=linear_kernel.......................
# [CV 4/5; 26/96] END C=10, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 26/96] START C=10, gamma=1, kernel=linear_kernel.......................
# [CV 5/5; 26/96] END C=10, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 27/96] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 27/96] END C=10, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.6s
# [CV 2/5; 27/96] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 27/96] END C=10, gamma=0.1, kernel=rbf;, score=0.832 total time=   0.6s
# [CV 3/5; 27/96] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 27/96] END C=10, gamma=0.1, kernel=rbf;, score=0.824 total time=   0.6s
# [CV 4/5; 27/96] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 27/96] END C=10, gamma=0.1, kernel=rbf;, score=0.837 total time=   0.6s
# [CV 5/5; 27/96] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 27/96] END C=10, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.6s
# [CV 1/5; 28/96] START C=10, gamma=0.1, kernel=linear_kernel.....................
# [CV 1/5; 28/96] END C=10, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 28/96] START C=10, gamma=0.1, kernel=linear_kernel.....................
# [CV 2/5; 28/96] END C=10, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 28/96] START C=10, gamma=0.1, kernel=linear_kernel.....................
# [CV 3/5; 28/96] END C=10, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 28/96] START C=10, gamma=0.1, kernel=linear_kernel.....................
# [CV 4/5; 28/96] END C=10, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 28/96] START C=10, gamma=0.1, kernel=linear_kernel.....................
# [CV 5/5; 28/96] END C=10, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 29/96] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 29/96] END C=10, gamma=0.001, kernel=rbf;, score=0.678 total time=   0.7s
# [CV 2/5; 29/96] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 29/96] END C=10, gamma=0.001, kernel=rbf;, score=0.681 total time=   0.7s
# [CV 3/5; 29/96] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 29/96] END C=10, gamma=0.001, kernel=rbf;, score=0.686 total time=   0.6s
# [CV 4/5; 29/96] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 29/96] END C=10, gamma=0.001, kernel=rbf;, score=0.676 total time=   0.7s
# [CV 5/5; 29/96] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 29/96] END C=10, gamma=0.001, kernel=rbf;, score=0.712 total time=   0.7s
# [CV 1/5; 30/96] START C=10, gamma=0.001, kernel=linear_kernel...................
# [CV 1/5; 30/96] END C=10, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 30/96] START C=10, gamma=0.001, kernel=linear_kernel...................
# [CV 2/5; 30/96] END C=10, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 30/96] START C=10, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 30/96] END C=10, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 30/96] START C=10, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 30/96] END C=10, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 30/96] START C=10, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 30/96] END C=10, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 31/96] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 31/96] END C=10, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 2/5; 31/96] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 31/96] END C=10, gamma=0.0001, kernel=rbf;, score=0.674 total time=   0.7s
# [CV 3/5; 31/96] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 31/96] END C=10, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 4/5; 31/96] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 31/96] END C=10, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.7s
# [CV 5/5; 31/96] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 31/96] END C=10, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.7s
# [CV 1/5; 32/96] START C=10, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 32/96] END C=10, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 32/96] START C=10, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 32/96] END C=10, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 32/96] START C=10, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 32/96] END C=10, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 32/96] START C=10, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 32/96] END C=10, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 32/96] START C=10, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 32/96] END C=10, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 33/96] START C=12, gamma=1, kernel=rbf.................................
# [CV 1/5; 33/96] END ..C=12, gamma=1, kernel=rbf;, score=0.871 total time=   0.9s
# [CV 2/5; 33/96] START C=12, gamma=1, kernel=rbf.................................
# [CV 2/5; 33/96] END ..C=12, gamma=1, kernel=rbf;, score=0.879 total time=   1.0s
# [CV 3/5; 33/96] START C=12, gamma=1, kernel=rbf.................................
# [CV 3/5; 33/96] END ..C=12, gamma=1, kernel=rbf;, score=0.880 total time=   1.0s
# [CV 4/5; 33/96] START C=12, gamma=1, kernel=rbf.................................
# [CV 4/5; 33/96] END ..C=12, gamma=1, kernel=rbf;, score=0.867 total time=   0.9s
# [CV 5/5; 33/96] START C=12, gamma=1, kernel=rbf.................................
# [CV 5/5; 33/96] END ..C=12, gamma=1, kernel=rbf;, score=0.860 total time=   1.0s
# [CV 1/5; 34/96] START C=12, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 34/96] END C=12, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 34/96] START C=12, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 34/96] END C=12, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 34/96] START C=12, gamma=1, kernel=linear_kernel.......................
# [CV 3/5; 34/96] END C=12, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 34/96] START C=12, gamma=1, kernel=linear_kernel.......................
# [CV 4/5; 34/96] END C=12, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 34/96] START C=12, gamma=1, kernel=linear_kernel.......................
# [CV 5/5; 34/96] END C=12, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 35/96] START C=12, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 35/96] END C=12, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.6s
# [CV 2/5; 35/96] START C=12, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 35/96] END C=12, gamma=0.1, kernel=rbf;, score=0.840 total time=   0.6s
# [CV 3/5; 35/96] START C=12, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 35/96] END C=12, gamma=0.1, kernel=rbf;, score=0.832 total time=   0.6s
# [CV 4/5; 35/96] START C=12, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 35/96] END C=12, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.6s
# [CV 5/5; 35/96] START C=12, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 35/96] END C=12, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.6s
# [CV 1/5; 36/96] START C=12, gamma=0.1, kernel=linear_kernel.....................
# [CV 1/5; 36/96] END C=12, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 36/96] START C=12, gamma=0.1, kernel=linear_kernel.....................
# [CV 2/5; 36/96] END C=12, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 36/96] START C=12, gamma=0.1, kernel=linear_kernel.....................
# [CV 3/5; 36/96] END C=12, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 36/96] START C=12, gamma=0.1, kernel=linear_kernel.....................
# [CV 4/5; 36/96] END C=12, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 36/96] START C=12, gamma=0.1, kernel=linear_kernel.....................
# [CV 5/5; 36/96] END C=12, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 37/96] START C=12, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 37/96] END C=12, gamma=0.001, kernel=rbf;, score=0.681 total time=   0.7s
# [CV 2/5; 37/96] START C=12, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 37/96] END C=12, gamma=0.001, kernel=rbf;, score=0.682 total time=   0.7s
# [CV 3/5; 37/96] START C=12, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 37/96] END C=12, gamma=0.001, kernel=rbf;, score=0.693 total time=   0.7s
# [CV 4/5; 37/96] START C=12, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 37/96] END C=12, gamma=0.001, kernel=rbf;, score=0.674 total time=   0.7s
# [CV 5/5; 37/96] START C=12, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 37/96] END C=12, gamma=0.001, kernel=rbf;, score=0.712 total time=   0.7s
# [CV 1/5; 38/96] START C=12, gamma=0.001, kernel=linear_kernel...................
# [CV 1/5; 38/96] END C=12, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 38/96] START C=12, gamma=0.001, kernel=linear_kernel...................
# [CV 2/5; 38/96] END C=12, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 38/96] START C=12, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 38/96] END C=12, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 38/96] START C=12, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 38/96] END C=12, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 38/96] START C=12, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 38/96] END C=12, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 39/96] START C=12, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 39/96] END C=12, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.7s
# [CV 2/5; 39/96] START C=12, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 39/96] END C=12, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 3/5; 39/96] START C=12, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 39/96] END C=12, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 4/5; 39/96] START C=12, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 39/96] END C=12, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 5/5; 39/96] START C=12, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 39/96] END C=12, gamma=0.0001, kernel=rbf;, score=0.705 total time=   0.7s
# [CV 1/5; 40/96] START C=12, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 40/96] END C=12, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 40/96] START C=12, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 40/96] END C=12, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 40/96] START C=12, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 40/96] END C=12, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 40/96] START C=12, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 40/96] END C=12, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 40/96] START C=12, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 40/96] END C=12, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 41/96] START C=16, gamma=1, kernel=rbf.................................
# [CV 1/5; 41/96] END ..C=16, gamma=1, kernel=rbf;, score=0.871 total time=   1.0s
# [CV 2/5; 41/96] START C=16, gamma=1, kernel=rbf.................................
# [CV 2/5; 41/96] END ..C=16, gamma=1, kernel=rbf;, score=0.879 total time=   0.9s
# [CV 3/5; 41/96] START C=16, gamma=1, kernel=rbf.................................
# [CV 3/5; 41/96] END ..C=16, gamma=1, kernel=rbf;, score=0.880 total time=   0.9s
# [CV 4/5; 41/96] START C=16, gamma=1, kernel=rbf.................................
# [CV 4/5; 41/96] END ..C=16, gamma=1, kernel=rbf;, score=0.866 total time=   1.0s
# [CV 5/5; 41/96] START C=16, gamma=1, kernel=rbf.................................
# [CV 5/5; 41/96] END ..C=16, gamma=1, kernel=rbf;, score=0.860 total time=   0.9s
# [CV 1/5; 42/96] START C=16, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 42/96] END C=16, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 42/96] START C=16, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 42/96] END C=16, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 42/96] START C=16, gamma=1, kernel=linear_kernel.......................
# [CV 3/5; 42/96] END C=16, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 42/96] START C=16, gamma=1, kernel=linear_kernel.......................
# [CV 4/5; 42/96] END C=16, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 42/96] START C=16, gamma=1, kernel=linear_kernel.......................
# [CV 5/5; 42/96] END C=16, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 43/96] START C=16, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 43/96] END C=16, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.6s
# [CV 2/5; 43/96] START C=16, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 43/96] END C=16, gamma=0.1, kernel=rbf;, score=0.845 total time=   0.6s
# [CV 3/5; 43/96] START C=16, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 43/96] END C=16, gamma=0.1, kernel=rbf;, score=0.837 total time=   0.6s
# [CV 4/5; 43/96] START C=16, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 43/96] END C=16, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.6s
# [CV 5/5; 43/96] START C=16, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 43/96] END C=16, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.6s
# [CV 1/5; 44/96] START C=16, gamma=0.1, kernel=linear_kernel.....................
# [CV 1/5; 44/96] END C=16, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 44/96] START C=16, gamma=0.1, kernel=linear_kernel.....................
# [CV 2/5; 44/96] END C=16, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 44/96] START C=16, gamma=0.1, kernel=linear_kernel.....................
# [CV 3/5; 44/96] END C=16, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 44/96] START C=16, gamma=0.1, kernel=linear_kernel.....................
# [CV 4/5; 44/96] END C=16, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 44/96] START C=16, gamma=0.1, kernel=linear_kernel.....................
# [CV 5/5; 44/96] END C=16, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 45/96] START C=16, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 45/96] END C=16, gamma=0.001, kernel=rbf;, score=0.682 total time=   0.7s
# [CV 2/5; 45/96] START C=16, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 45/96] END C=16, gamma=0.001, kernel=rbf;, score=0.687 total time=   0.7s
# [CV 3/5; 45/96] START C=16, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 45/96] END C=16, gamma=0.001, kernel=rbf;, score=0.702 total time=   0.7s
# [CV 4/5; 45/96] START C=16, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 45/96] END C=16, gamma=0.001, kernel=rbf;, score=0.677 total time=   0.7s
# [CV 5/5; 45/96] START C=16, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 45/96] END C=16, gamma=0.001, kernel=rbf;, score=0.718 total time=   0.7s
# [CV 1/5; 46/96] START C=16, gamma=0.001, kernel=linear_kernel...................
# [CV 1/5; 46/96] END C=16, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 46/96] START C=16, gamma=0.001, kernel=linear_kernel...................
# [CV 2/5; 46/96] END C=16, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 46/96] START C=16, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 46/96] END C=16, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 46/96] START C=16, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 46/96] END C=16, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 46/96] START C=16, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 46/96] END C=16, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 47/96] START C=16, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 47/96] END C=16, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 2/5; 47/96] START C=16, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 47/96] END C=16, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.7s
# [CV 3/5; 47/96] START C=16, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 47/96] END C=16, gamma=0.0001, kernel=rbf;, score=0.672 total time=   0.7s
# [CV 4/5; 47/96] START C=16, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 47/96] END C=16, gamma=0.0001, kernel=rbf;, score=0.673 total time=   1.0s
# [CV 5/5; 47/96] START C=16, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 47/96] END C=16, gamma=0.0001, kernel=rbf;, score=0.703 total time=   1.2s
# [CV 1/5; 48/96] START C=16, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 48/96] END C=16, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 48/96] START C=16, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 48/96] END C=16, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 48/96] START C=16, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 48/96] END C=16, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 48/96] START C=16, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 48/96] END C=16, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 48/96] START C=16, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 48/96] END C=16, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 49/96] START C=20, gamma=1, kernel=rbf.................................
# [CV 1/5; 49/96] END ..C=20, gamma=1, kernel=rbf;, score=0.871 total time=   1.0s
# [CV 2/5; 49/96] START C=20, gamma=1, kernel=rbf.................................
# [CV 2/5; 49/96] END ..C=20, gamma=1, kernel=rbf;, score=0.878 total time=   1.0s
# [CV 3/5; 49/96] START C=20, gamma=1, kernel=rbf.................................
# [CV 3/5; 49/96] END ..C=20, gamma=1, kernel=rbf;, score=0.880 total time=   1.0s
# [CV 4/5; 49/96] START C=20, gamma=1, kernel=rbf.................................
# [CV 4/5; 49/96] END ..C=20, gamma=1, kernel=rbf;, score=0.866 total time=   1.0s
# [CV 5/5; 49/96] START C=20, gamma=1, kernel=rbf.................................
# [CV 5/5; 49/96] END ..C=20, gamma=1, kernel=rbf;, score=0.857 total time=   1.1s
# [CV 1/5; 50/96] START C=20, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 50/96] END C=20, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 50/96] START C=20, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 50/96] END C=20, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 50/96] START C=20, gamma=1, kernel=linear_kernel.......................
# [CV 3/5; 50/96] END C=20, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 50/96] START C=20, gamma=1, kernel=linear_kernel.......................
# [CV 4/5; 50/96] END C=20, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 50/96] START C=20, gamma=1, kernel=linear_kernel.......................
# [CV 5/5; 50/96] END C=20, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 51/96] START C=20, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 51/96] END C=20, gamma=0.1, kernel=rbf;, score=0.843 total time=   0.9s
# [CV 2/5; 51/96] START C=20, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 51/96] END C=20, gamma=0.1, kernel=rbf;, score=0.852 total time=   0.6s
# [CV 3/5; 51/96] START C=20, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 51/96] END C=20, gamma=0.1, kernel=rbf;, score=0.836 total time=   0.7s
# [CV 4/5; 51/96] START C=20, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 51/96] END C=20, gamma=0.1, kernel=rbf;, score=0.840 total time=   0.7s
# [CV 5/5; 51/96] START C=20, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 51/96] END C=20, gamma=0.1, kernel=rbf;, score=0.842 total time=   0.7s
# [CV 1/5; 52/96] START C=20, gamma=0.1, kernel=linear_kernel.....................
# [CV 1/5; 52/96] END C=20, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 52/96] START C=20, gamma=0.1, kernel=linear_kernel.....................
# [CV 2/5; 52/96] END C=20, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 52/96] START C=20, gamma=0.1, kernel=linear_kernel.....................
# [CV 3/5; 52/96] END C=20, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 52/96] START C=20, gamma=0.1, kernel=linear_kernel.....................
# [CV 4/5; 52/96] END C=20, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 52/96] START C=20, gamma=0.1, kernel=linear_kernel.....................
# [CV 5/5; 52/96] END C=20, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 53/96] START C=20, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 53/96] END C=20, gamma=0.001, kernel=rbf;, score=0.683 total time=   0.7s
# [CV 2/5; 53/96] START C=20, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 53/96] END C=20, gamma=0.001, kernel=rbf;, score=0.692 total time=   0.7s
# [CV 3/5; 53/96] START C=20, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 53/96] END C=20, gamma=0.001, kernel=rbf;, score=0.705 total time=   0.7s
# [CV 4/5; 53/96] START C=20, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 53/96] END C=20, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.6s
# [CV 5/5; 53/96] START C=20, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 53/96] END C=20, gamma=0.001, kernel=rbf;, score=0.718 total time=   0.7s
# [CV 1/5; 54/96] START C=20, gamma=0.001, kernel=linear_kernel...................
# [CV 1/5; 54/96] END C=20, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 54/96] START C=20, gamma=0.001, kernel=linear_kernel...................
# [CV 2/5; 54/96] END C=20, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 54/96] START C=20, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 54/96] END C=20, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 54/96] START C=20, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 54/96] END C=20, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 54/96] START C=20, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 54/96] END C=20, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 55/96] START C=20, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 55/96] END C=20, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.9s
# [CV 2/5; 55/96] START C=20, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 55/96] END C=20, gamma=0.0001, kernel=rbf;, score=0.668 total time=   1.3s
# [CV 3/5; 55/96] START C=20, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 55/96] END C=20, gamma=0.0001, kernel=rbf;, score=0.673 total time=   1.4s
# [CV 4/5; 55/96] START C=20, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 55/96] END C=20, gamma=0.0001, kernel=rbf;, score=0.669 total time=   1.7s
# [CV 5/5; 55/96] START C=20, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 55/96] END C=20, gamma=0.0001, kernel=rbf;, score=0.703 total time=   1.4s
# [CV 1/5; 56/96] START C=20, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 56/96] END C=20, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 56/96] START C=20, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 56/96] END C=20, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 56/96] START C=20, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 56/96] END C=20, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 56/96] START C=20, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 56/96] END C=20, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 56/96] START C=20, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 56/96] END C=20, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 57/96] START C=30, gamma=1, kernel=rbf.................................
# [CV 1/5; 57/96] END ..C=30, gamma=1, kernel=rbf;, score=0.870 total time=   1.7s
# [CV 2/5; 57/96] START C=30, gamma=1, kernel=rbf.................................
# [CV 2/5; 57/96] END ..C=30, gamma=1, kernel=rbf;, score=0.878 total time=   1.0s
# [CV 3/5; 57/96] START C=30, gamma=1, kernel=rbf.................................
# [CV 3/5; 57/96] END ..C=30, gamma=1, kernel=rbf;, score=0.878 total time=   1.0s
# [CV 4/5; 57/96] START C=30, gamma=1, kernel=rbf.................................
# [CV 4/5; 57/96] END ..C=30, gamma=1, kernel=rbf;, score=0.866 total time=   0.9s
# [CV 5/5; 57/96] START C=30, gamma=1, kernel=rbf.................................
# [CV 5/5; 57/96] END ..C=30, gamma=1, kernel=rbf;, score=0.857 total time=   1.0s
# [CV 1/5; 58/96] START C=30, gamma=1, kernel=linear_kernel.......................
# [CV 1/5; 58/96] END C=30, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 58/96] START C=30, gamma=1, kernel=linear_kernel.......................
# [CV 2/5; 58/96] END C=30, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 58/96] START C=30, gamma=1, kernel=linear_kernel.......................
# ...
# [CV 3/5; 78/96] START C=80, gamma=0.001, kernel=linear_kernel...................
# [CV 3/5; 78/96] END C=80, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 78/96] START C=80, gamma=0.001, kernel=linear_kernel...................
# [CV 4/5; 78/96] END C=80, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 78/96] START C=80, gamma=0.001, kernel=linear_kernel...................
# [CV 5/5; 78/96] END C=80, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 79/96] START C=80, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 79/96] END C=80, gamma=0.0001, kernel=rbf;, score=0.668 total time=   0.7s
# [CV 2/5; 79/96] START C=80, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 79/96] END C=80, gamma=0.0001, kernel=rbf;, score=0.676 total time=   0.7s
# [CV 3/5; 79/96] START C=80, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 79/96] END C=80, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.7s
# [CV 4/5; 79/96] START C=80, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 79/96] END C=80, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.7s
# [CV 5/5; 79/96] START C=80, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 79/96] END C=80, gamma=0.0001, kernel=rbf;, score=0.701 total time=   0.7s
# [CV 1/5; 80/96] START C=80, gamma=0.0001, kernel=linear_kernel..................
# [CV 1/5; 80/96] END C=80, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 80/96] START C=80, gamma=0.0001, kernel=linear_kernel..................
# [CV 2/5; 80/96] END C=80, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 80/96] START C=80, gamma=0.0001, kernel=linear_kernel..................
# [CV 3/5; 80/96] END C=80, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 80/96] START C=80, gamma=0.0001, kernel=linear_kernel..................
# [CV 4/5; 80/96] END C=80, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 80/96] START C=80, gamma=0.0001, kernel=linear_kernel..................
# [CV 5/5; 80/96] END C=80, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 81/96] START C=100, gamma=1, kernel=rbf................................
# [CV 1/5; 81/96] END .C=100, gamma=1, kernel=rbf;, score=0.869 total time=   0.9s
# [CV 2/5; 81/96] START C=100, gamma=1, kernel=rbf................................
# [CV 2/5; 81/96] END .C=100, gamma=1, kernel=rbf;, score=0.878 total time=   0.9s
# [CV 3/5; 81/96] START C=100, gamma=1, kernel=rbf................................
# [CV 3/5; 81/96] END .C=100, gamma=1, kernel=rbf;, score=0.874 total time=   1.0s
# [CV 4/5; 81/96] START C=100, gamma=1, kernel=rbf................................
# [CV 4/5; 81/96] END .C=100, gamma=1, kernel=rbf;, score=0.865 total time=   1.0s
# [CV 5/5; 81/96] START C=100, gamma=1, kernel=rbf................................
# [CV 5/5; 81/96] END .C=100, gamma=1, kernel=rbf;, score=0.857 total time=   0.9s
# [CV 1/5; 82/96] START C=100, gamma=1, kernel=linear_kernel......................
# [CV 1/5; 82/96] END C=100, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 82/96] START C=100, gamma=1, kernel=linear_kernel......................
# [CV 2/5; 82/96] END C=100, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 82/96] START C=100, gamma=1, kernel=linear_kernel......................
# [CV 3/5; 82/96] END C=100, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 82/96] START C=100, gamma=1, kernel=linear_kernel......................
# [CV 4/5; 82/96] END C=100, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 82/96] START C=100, gamma=1, kernel=linear_kernel......................
# [CV 5/5; 82/96] END C=100, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 83/96] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 83/96] END C=100, gamma=0.1, kernel=rbf;, score=0.846 total time=   0.9s
# [CV 2/5; 83/96] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 83/96] END C=100, gamma=0.1, kernel=rbf;, score=0.857 total time=   1.0s
# [CV 3/5; 83/96] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 83/96] END C=100, gamma=0.1, kernel=rbf;, score=0.857 total time=   1.0s
# [CV 4/5; 83/96] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 83/96] END C=100, gamma=0.1, kernel=rbf;, score=0.848 total time=   1.0s
# [CV 5/5; 83/96] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 83/96] END C=100, gamma=0.1, kernel=rbf;, score=0.835 total time=   1.0s
# [CV 1/5; 84/96] START C=100, gamma=0.1, kernel=linear_kernel....................
# [CV 1/5; 84/96] END C=100, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 84/96] START C=100, gamma=0.1, kernel=linear_kernel....................
# [CV 2/5; 84/96] END C=100, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 84/96] START C=100, gamma=0.1, kernel=linear_kernel....................
# [CV 3/5; 84/96] END C=100, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 84/96] START C=100, gamma=0.1, kernel=linear_kernel....................
# [CV 4/5; 84/96] END C=100, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 84/96] START C=100, gamma=0.1, kernel=linear_kernel....................
# [CV 5/5; 84/96] END C=100, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 85/96] START C=100, gamma=0.001, kernel=rbf............................
# [CV 1/5; 85/96] END C=100, gamma=0.001, kernel=rbf;, score=0.705 total time=   0.7s
# [CV 2/5; 85/96] START C=100, gamma=0.001, kernel=rbf............................
# [CV 2/5; 85/96] END C=100, gamma=0.001, kernel=rbf;, score=0.718 total time=   0.7s
# [CV 3/5; 85/96] START C=100, gamma=0.001, kernel=rbf............................
# [CV 3/5; 85/96] END C=100, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.7s
# [CV 4/5; 85/96] START C=100, gamma=0.001, kernel=rbf............................
# [CV 4/5; 85/96] END C=100, gamma=0.001, kernel=rbf;, score=0.703 total time=   0.7s
# [CV 5/5; 85/96] START C=100, gamma=0.001, kernel=rbf............................
# [CV 5/5; 85/96] END C=100, gamma=0.001, kernel=rbf;, score=0.735 total time=   0.7s
# [CV 1/5; 86/96] START C=100, gamma=0.001, kernel=linear_kernel..................
# [CV 1/5; 86/96] END C=100, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 86/96] START C=100, gamma=0.001, kernel=linear_kernel..................
# [CV 2/5; 86/96] END C=100, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 86/96] START C=100, gamma=0.001, kernel=linear_kernel..................
# [CV 3/5; 86/96] END C=100, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 86/96] START C=100, gamma=0.001, kernel=linear_kernel..................
# [CV 4/5; 86/96] END C=100, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 86/96] START C=100, gamma=0.001, kernel=linear_kernel..................
# [CV 5/5; 86/96] END C=100, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 87/96] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 1/5; 87/96] END C=100, gamma=0.0001, kernel=rbf;, score=0.668 total time=   0.7s
# [CV 2/5; 87/96] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 2/5; 87/96] END C=100, gamma=0.0001, kernel=rbf;, score=0.676 total time=   0.7s
# [CV 3/5; 87/96] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 3/5; 87/96] END C=100, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.7s
# [CV 4/5; 87/96] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 4/5; 87/96] END C=100, gamma=0.0001, kernel=rbf;, score=0.670 total time=   0.7s
# [CV 5/5; 87/96] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 5/5; 87/96] END C=100, gamma=0.0001, kernel=rbf;, score=0.699 total time=   0.7s
# [CV 1/5; 88/96] START C=100, gamma=0.0001, kernel=linear_kernel.................
# [CV 1/5; 88/96] END C=100, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 88/96] START C=100, gamma=0.0001, kernel=linear_kernel.................
# [CV 2/5; 88/96] END C=100, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 88/96] START C=100, gamma=0.0001, kernel=linear_kernel.................
# [CV 3/5; 88/96] END C=100, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 88/96] START C=100, gamma=0.0001, kernel=linear_kernel.................
# [CV 4/5; 88/96] END C=100, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 88/96] START C=100, gamma=0.0001, kernel=linear_kernel.................
# [CV 5/5; 88/96] END C=100, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 89/96] START C=1000, gamma=1, kernel=rbf...............................
# [CV 1/5; 89/96] END C=1000, gamma=1, kernel=rbf;, score=0.869 total time=   0.9s
# [CV 2/5; 89/96] START C=1000, gamma=1, kernel=rbf...............................
# [CV 2/5; 89/96] END C=1000, gamma=1, kernel=rbf;, score=0.878 total time=   0.9s
# [CV 3/5; 89/96] START C=1000, gamma=1, kernel=rbf...............................
# [CV 3/5; 89/96] END C=1000, gamma=1, kernel=rbf;, score=0.874 total time=   1.0s
# [CV 4/5; 89/96] START C=1000, gamma=1, kernel=rbf...............................
# [CV 4/5; 89/96] END C=1000, gamma=1, kernel=rbf;, score=0.865 total time=   1.0s
# [CV 5/5; 89/96] START C=1000, gamma=1, kernel=rbf...............................
# [CV 5/5; 89/96] END C=1000, gamma=1, kernel=rbf;, score=0.857 total time=   1.4s
# [CV 1/5; 90/96] START C=1000, gamma=1, kernel=linear_kernel.....................
# [CV 1/5; 90/96] END C=1000, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 90/96] START C=1000, gamma=1, kernel=linear_kernel.....................
# [CV 2/5; 90/96] END C=1000, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 90/96] START C=1000, gamma=1, kernel=linear_kernel.....................
# [CV 3/5; 90/96] END C=1000, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 90/96] START C=1000, gamma=1, kernel=linear_kernel.....................
# [CV 4/5; 90/96] END C=1000, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 90/96] START C=1000, gamma=1, kernel=linear_kernel.....................
# [CV 5/5; 90/96] END C=1000, gamma=1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 91/96] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 91/96] END C=1000, gamma=0.1, kernel=rbf;, score=0.841 total time=   2.0s
# [CV 2/5; 91/96] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 91/96] END C=1000, gamma=0.1, kernel=rbf;, score=0.821 total time=   1.8s
# [CV 3/5; 91/96] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 91/96] END C=1000, gamma=0.1, kernel=rbf;, score=0.823 total time=   1.6s
# [CV 4/5; 91/96] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 4/5; 91/96] END C=1000, gamma=0.1, kernel=rbf;, score=0.842 total time=   1.9s
# [CV 5/5; 91/96] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 91/96] END C=1000, gamma=0.1, kernel=rbf;, score=0.821 total time=   1.8s
# [CV 1/5; 92/96] START C=1000, gamma=0.1, kernel=linear_kernel...................
# [CV 1/5; 92/96] END C=1000, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 92/96] START C=1000, gamma=0.1, kernel=linear_kernel...................
# [CV 2/5; 92/96] END C=1000, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 92/96] START C=1000, gamma=0.1, kernel=linear_kernel...................
# [CV 3/5; 92/96] END C=1000, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 92/96] START C=1000, gamma=0.1, kernel=linear_kernel...................
# [CV 4/5; 92/96] END C=1000, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 92/96] START C=1000, gamma=0.1, kernel=linear_kernel...................
# [CV 5/5; 92/96] END C=1000, gamma=0.1, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 93/96] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 1/5; 93/96] END C=1000, gamma=0.001, kernel=rbf;, score=0.755 total time=   1.0s
# [CV 2/5; 93/96] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 2/5; 93/96] END C=1000, gamma=0.001, kernel=rbf;, score=0.755 total time=   0.9s
# [CV 3/5; 93/96] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 3/5; 93/96] END C=1000, gamma=0.001, kernel=rbf;, score=0.761 total time=   0.9s
# [CV 4/5; 93/96] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 4/5; 93/96] END C=1000, gamma=0.001, kernel=rbf;, score=0.753 total time=   0.9s
# [CV 5/5; 93/96] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 5/5; 93/96] END C=1000, gamma=0.001, kernel=rbf;, score=0.773 total time=   1.0s
# [CV 1/5; 94/96] START C=1000, gamma=0.001, kernel=linear_kernel.................
# [CV 1/5; 94/96] END C=1000, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 94/96] START C=1000, gamma=0.001, kernel=linear_kernel.................
# [CV 2/5; 94/96] END C=1000, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 94/96] START C=1000, gamma=0.001, kernel=linear_kernel.................
# [CV 3/5; 94/96] END C=1000, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 94/96] START C=1000, gamma=0.001, kernel=linear_kernel.................
# [CV 4/5; 94/96] END C=1000, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 94/96] START C=1000, gamma=0.001, kernel=linear_kernel.................
# [CV 5/5; 94/96] END C=1000, gamma=0.001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 1/5; 95/96] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 95/96] END C=1000, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.7s
# [CV 2/5; 95/96] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 2/5; 95/96] END C=1000, gamma=0.0001, kernel=rbf;, score=0.684 total time=   0.7s
# [CV 3/5; 95/96] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 3/5; 95/96] END C=1000, gamma=0.0001, kernel=rbf;, score=0.688 total time=   0.8s
# [CV 4/5; 95/96] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 4/5; 95/96] END C=1000, gamma=0.0001, kernel=rbf;, score=0.673 total time=   0.7s
# [CV 5/5; 95/96] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 5/5; 95/96] END C=1000, gamma=0.0001, kernel=rbf;, score=0.710 total time=   0.7s
# [CV 1/5; 96/96] START C=1000, gamma=0.0001, kernel=linear_kernel................
# [CV 1/5; 96/96] END C=1000, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 2/5; 96/96] START C=1000, gamma=0.0001, kernel=linear_kernel................
# [CV 2/5; 96/96] END C=1000, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 3/5; 96/96] START C=1000, gamma=0.0001, kernel=linear_kernel................
# [CV 3/5; 96/96] END C=1000, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 4/5; 96/96] START C=1000, gamma=0.0001, kernel=linear_kernel................
# [CV 4/5; 96/96] END C=1000, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# [CV 5/5; 96/96] START C=1000, gamma=0.0001, kernel=linear_kernel................
# [CV 5/5; 96/96] END C=1000, gamma=0.0001, kernel=linear_kernel;, score=nan total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 8, 10, 12, 16, 20, 30, 50, 80, 100,
#                                1000],
#                          'gamma': [1, 0.1, 0.001, 0.0001],
#                          'kernel': ['rbf', 'linear_kernel']},
#              verbose=100)

# %%
#getting the best parameters
grid.best_params_
# Out:
# {'C': 8, 'gamma': 1, 'kernel': 'rbf'}

# %%
svc_2 = SVC(C=8,gamma=1,kernel='rbf')

# %%
#Fitting on training dataset using the best parameters
svc_2.fit(X_train_res,y_train_res)
# Out:
# SVC(C=8, gamma=1)

# %%
#predicting on training and testing dataset after using the best parameters
y_pred_train_svm_grid = svc_2.predict(X_train_res)
y_pred_test_svm_grid = svc_2.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on SVM after Hyperparameter tuning

# %%
#Accuracy score, confusion matrix and classification report of training 
acc_svm_train_grid = accuracy_score(y_train_res,y_pred_train_svm_grid)*100
print(acc_svm_train_grid)
cmm_svm_train_grid = confusion_matrix(y_pred_train_svm_grid,y_train_res)
print(cmm_svm_train_grid)
crr_svm_train_grid = classification_report(y_pred_train_svm_grid,y_train_res)
print(crr_svm_train_grid)
# Out:
# 99.8989898989899
# [[1970    0]
#  [   4 1986]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1970
#            1       1.00      1.00      1.00      1990
#
#     accuracy                           1.00      3960
#    macro avg       1.00      1.00      1.00      3960
# weighted avg       1.00      1.00      1.00      3960

# %%
#Accuracy score, confusion matrix and classification report of testing
acc_svm_test_grid = accuracy_score(y_test_res,y_pred_test_svm_grid)*100
print(acc_svm_test_grid)
print(confusion_matrix(y_pred_test_svm_grid,y_test_res))
print(classification_report(y_pred_test_svm_grid,y_test_res))
# Out:
# 89.2226148409894
# [[758  86]
#  [ 97 757]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       844
#            1       0.90      0.89      0.89       854
#
#     accuracy                           0.89      1698
#    macro avg       0.89      0.89      0.89      1698
# weighted avg       0.89      0.89      0.89      1698

# %% [markdown]
# # Comparision of evaluation metrics of the models being used

# %%
models = ['Logestic','RFC','KNN','SVM','Tuned SVM']
acc = [log_acc_train,rfc_acc_train,knn_acc_train,acc_svm_train,acc_svm_train_grid]

sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
plt.ylabel("Accuracy")
plt.xlabel("Machine Learning Model")
sns.barplot(x= models, y= acc)
plt.title('Comparision of Accuracy of Training data among the models')
plt.show()

# %% [markdown]
# Here we can clearly observe that Tuned SVM , Knn and RFC are really performing well on training data..

# %%
models = ['logestic','RFC','KNN','SVM','Tuned SVM']
acc = [log_acc_test,rfc_acc_test,knn_acc_test,acc_svm_test,acc_svm_test_grid]

sns.set_style("whitegrid")
plt.figure(figsize=(13,7))
plt.ylabel("Accuracy")
plt.xlabel("Machine Learning Model")
sns.barplot(x= models, y= acc)
plt.title('Comparision of Accuracy of Testing data among the models')
plt.show()

# %% [markdown]
# Here also Tuned SVM,KNN and RFC are performing well but in tuned SVM we saw the overfitting but Accuracy was imporved with hyper parameter tuning

# %% [markdown]
# *The following columns lie in the range:
#
# totChol: 150 to 300 , sysBP: 100 to 150, diaBP: 60 to 100 ,BMI: 20 to 30, heartRate: 50 to 100 glucose: 50 to 150 *Mid-age groups ranging from the age of 38 - 46 have more number of currentSmokers
#
# * No currentSmokers observed below the age of 32
# * Maximum age for a currentSmokers is 70
# * Males have shown a slightly higher risk of coronary heart disease TenYearCHD.
# * Mid-age groups ranging from the age of 38 - 46 have more number of currentSmokers
# * No currentSmokers observed below the age of 32
# * Low cigsPerDay comes with lower risk of CHD.
# * Those who don't smoke, i.e., with a cigsPerDay of 0.0 has a really low risk of contracting the disease
# * Minor relation of higher risk of TenYearCHD found with higher sysBP AND higher diaBP
# * Majority of people with sysBP ranging from 72 - 130 has lower chance of contracting the disease.
# * Majority of people with diaBP ranging upto 80.0 has lower chance of contracting the disease.
# Again, age, total cholesterol level, diastolic blood pressure, BMI, and glucose level are the main culprits leading to heart diseases,especially CHD.
# These models show that our analysis is highly accurate.
#
#
# * we get more then 80% of accuracy in 3/5 models..
#
#
# * Tuned SVM,KNN and RFC are performing well but in tuned SVM we saw the overfitting but Accuracy was imporved with hyper parameter tuning
#
#
# *  we will make our code more effective to bulid a function to take inputs from user..  and gives the results as like diagonsis center

# %%
def Almabetter_cardiovescular_diagonasis():
    print("Welcome to Almabetter_cardiovescular_diagonasis:")
    print("Hay I'm Dr.ArunTeja Lonka , from AlmaBetter,")
    name = input("Please Enter your Name:\n")
    print(f'{name}, Please Fill below data carefully to get reports:')
    age = int(input(f'Hello {name},please enter your age:\n  '))
    Gender = str(input(f"hay {name} can you confirm your Gender: (Type: male/female/other)"))
    if Gender == 'male':
        sex = 0
    else:
        sex = 1
    smoking = input(f"{name}, Are you smoker? (yes/no)")
    print("use small letter only for type yes/no")
    if smoking == 'yes':
        smo = 1
        cig_per_day = int(input(f"How many packets you smoke per day, {name}"))
    else:
        smo = 0
        cig_per_day = 0
    bp_med = input(f"{name} are you using any blood pressure medication: (type:yes/no)")
    if bp_med == 'yes':
        bp = 1
    else:
        bp = 0

    Prevalent_Stoke = input(f"hay,{name} have you face any heart stroke previously?:((type:yes/no) ")
    if Prevalent_Stoke == 'yes':
        p_s = 1
    else:
        p_s = 0
    Prevalent_Hyp = input(f"hay,{name} are you hypertensive?:((type:yes/no) ")
    if Prevalent_Hyp == 'yes':
        p_h = 1
    else:
        p_h = 0
    Diabetes = input(f"hay,{name} are you Diabetic?:((type:yes/no) ")
    if Diabetes == 'yes':
        dbt = 1
    else:
        dbt = 0
    Tot_chol = float(input(f"{name}, please enter your total cholesterol level \n "))
    #sys = float(input(f"{name}, please enter your systolic blood pressure rate :\n"))
    #dia_bp = float(input(f"{name}, please enter your dia blood pressure value:\n"))
    bmi = float(input(f"{name}, please enter your Body mass index(BMI)"))
    heart_rate = float(input(f"{name}, please enter your heart rate value:"))
    glocose = float(input("Enter your Glucose level:\n"))

    edu = int(input("Please enter your educational status (if  you are below 10th :type 1) \n (if you are 12+ : type 2) \n (if you are Graduate :type 3) \n (if you are above that : type 4)"))
    list = [age, edu, sex, smo, cig_per_day, bp,p_s, p_h, dbt, Tot_chol, bmi, heart_rate, glocose]
    inp = np.array(list)
    ip = inp.reshape((1, -1))
    print(f".............................{ip}................................................................")
    mp1 = rfc.predict(ip)
    mp2 = svc_2.predict(ip)
    if mp1 == 0:
      if mp1==mp2:
        print(f"Hay {name} you are safe you don't have any 10-year risk of coronary heart disease CHD , You can Go home Happily")
        print(f"Thank you for visiting,Keep smiling {name}")
      else:
        print(".........................sever problem.........................")  
        print("Please retry again")
    if mp1 == 1:
      print(f"Hay{name} you have 10-year risk of coronary heart disease CHD, please consult a Doctor as Early as posible:  ") 
      print(f"Don't worry {name}, I will book an appoinment to consult a one the best doctor in city,we are always here to help you:")
      print(f"Thank you for visiting,Keep smiling {name} and don't smoke")

# %%
df_copy.head(2)
# Out:
#    age  education  sex  is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   64        2.0    1           1         3.0     0.0                0
# 1   36        4.0    0           0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol        BMI  heartRate  glucose  TenYearCHD
# 0             0         0    221.0  25.794964       88.0     80.0           1
# 1             1         0    212.0  29.590000       72.0     75.0           0

# %%
Almabetter_cardiovescular_diagonasis()
# Out:
# Welcome to Almabetter_cardiovescular_diagonasis:
# Hay I'm Dr.ArunTeja Lonka , from AlmaBetter,
# Please Enter your Name:
# Upasana Kumari
# Upasana Kumari, Please Fill below data carefully to get reports:
# Hello Upasana Kumari,please enter your age:
#   64
# hay Upasana Kumari can you confirm your Gender: (Type: male/female/other)female
# Upasana Kumari, Are you smoker? (yes/no)yes
# use small letter only for type yes/no
# How many packets you smoke per day, Upasana Kumari3
# Upasana Kumari are you using any blood pressure medication: (type:yes/no)no
# hay,Upasana Kumari have you face any heart stroke previously?:((type:yes/no) no
# hay,Upasana Kumari are you hypertensive?:((type:yes/no) no
# hay,Upasana Kumari are you Diabetic?:((type:yes/no) no
# Upasana Kumari, please enter your total cholesterol level
#  221
# Upasana Kumari, please enter your Body mass index(BMI)25.7
# Upasana Kumari, please enter your heart rate value:88
# Enter your Glucose level:
# 80
# Please enter your educational status (if  you are below 10th :type 1)
#  (if you are 12+ : type 2)
#  (if you are Graduate :type 3)
#  (if you are above that : type 4)2
# .............................[[ 64.    2.    1.    1.    3.    0.    0.    0.    0.  221.   25.7  88.
#    80. ]]................................................................
# HayUpasana Kumari you have 10-year risk of coronary heart disease CHD, please consult a Doctor as Early as posible:
# Don't worry Upasana Kumari, I will book an appoinment to consult a one the best doctor in city,we are always here to help you:
# Thank you for visiting,Keep smiling Upasana Kumari and don't smoke

# %% [markdown]
# I mentioned row 1 detailes , and i get correct Prediction , so My model was good to use in Almabetter_cardiovescular_diagonasis center .

# %% [markdown]
# THANK YOU...
